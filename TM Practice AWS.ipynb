# %% [markdown]
# # Getting set up

# %%
#importing the AWS folder
import sys
sys.path.append('/Users/tobywarner/Dropbox/textmining/workbooks/AWS/AfricanWritersSeries/')
import nltk
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /Users/tobywarner/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %%
#removing the lower function from line to enable POS tagging to work better. is there a better fix?
def tokenize_fast(line):
    import re
    # tokenize using reg ex (fast)
    tokens = re.findall("[A-Z]{2,}(?![a-z])|[A-Z][a-z]+(?=[A-Z])|[\'\w\-]+",line)
    # remove punctuation on either end
    from string import punctuation
    tokens = [tok.strip(punctuation) for tok in tokens]
    # make sure each thing in list isn't empty
    tokens = [tok for tok in tokens if tok]
    return tokens

# %%
from aws_novels import *

# %%
C = get_corpus()

# %%
textastrings = []
for t in C.texts(): textastrings.append(t.txt)

# %%
C.meta
# Out:
#                                                                              author  \
# id
# Ngugi,The_River_Between,1965                    Ngugi wa Thiong'o (as Ngugi, James)
# Ngugi,A_Grain_of_Wheat,1967                     Ngugi wa Thiong'o (as Ngugi, James)
# Armah,The_Beautyful_Ones_Are_Not_Yet_Born,1969                      Armah, Ayi Kwei
# Ousmane,God's_Bits_of_Wood,1970                                    Ousmane, Sembene
# Soyinka,The_Interpreters,1970                                         Soyinka, Wole
# ...                                                                             ...
# Tadjo,As_the_Crow_Flies,2001                                       Tadjo, Veronique
# Pepetela_,Return_of_the_Water_Spirit,2002                                 Pepetela
# Tadjo,The_Shadow_of_Imana,2002                                     Tadjo, Veronique
# Aidoo,Changes,2003                                                  Aidoo, Ama Ata
# Mengara,Mema,2003                                                   Mengara, Daniel
#
#                                                                                             title  \
# id
# Ngugi,The_River_Between,1965                                                    The River Between
# Ngugi,A_Grain_of_Wheat,1967                                                     A Grain of Wheat.
# Armah,The_Beautyful_Ones_Are_Not_Yet_Born,1969  The Beautyful Ones Are Not Yet Born. (Boston: ...
# Ousmane,God's_Bits_of_Wood,1970                                               God's Bits of Wood.
# Soyinka,The_Interpreters,1970                                                  The Interpreters.
# ...                                                                                           ...
# Tadjo,As_the_Crow_Flies,2001                                                    As the Crow Flies
# Pepetela_,Return_of_the_Water_Spirit,2002                              Return of the Water Spirit
# Tadjo,The_Shadow_of_Imana,2002                                                The Shadow of Imana
# Aidoo,Changes,2003                                                          Changes: A Love Story
# Mengara,Mema,2003                                                                            Mema
#
#                                                 year  \
# id
# Ngugi,The_River_Between,1965                    1965
# Ngugi,A_Grain_of_Wheat,1967                     1967
# Armah,The_Beautyful_Ones_Are_Not_Yet_Born,1969  1969
# Ousmane,God's_Bits_of_Wood,1970                 1970
# Soyinka,The_Interpreters,1970                   1970
# ...                                              ...
# Tadjo,As_the_Crow_Flies,2001                    2001
# Pepetela_,Return_of_the_Water_Spirit,2002       2002
# Tadjo,The_Shadow_of_Imana,2002                  2002
# Aidoo,Changes,2003                              2003
# Mengara,Mema,2003                               2003
#
#                                                                                                fn  \
# id
# Ngugi,The_River_Between,1965                                     Ngugi,The_River_Between,1965.txt
# Ngugi,A_Grain_of_Wheat,1967                                       Ngugi,A_Grain_of_Wheat,1967.txt
# Armah,The_Beautyful_Ones_Are_Not_Yet_Born,1969  Armah,The_Beautyful_Ones_Are_Not_Yet_Born,1969...
# Ousmane,God's_Bits_of_Wood,1970                               Ousmane,God's_Bits_of_Wood,1970.txt
# Soyinka,The_Interpreters,1970                                   Soyinka,The_Interpreters,1970.txt
# ...                                                                                           ...
# Tadjo,As_the_Crow_Flies,2001                                     Tadjo,As_the_Crow_Flies,2001.txt
# Pepetela_,Return_of_the_Water_Spirit,2002           Pepetela_,Return_of_the_Water_Spirit,2002.txt
# Tadjo,The_Shadow_of_Imana,2002                                 Tadjo,The_Shadow_of_Imana,2002.txt
# Aidoo,Changes,2003                                                         Aidoo,Changes,2003.txt
# Mengara,Mema,2003                                                           Mengara,Mema,2003.txt
#
#                                                                 old_fn have  \
# id
# Ngugi,The_River_Between,1965                                            yes
# Ngugi,A_Grain_of_Wheat,1967                                             yes
# Armah,The_Beautyful_Ones_Are_Not_Yet_Born,1969                          yes
# Ousmane,God's_Bits_of_Wood,1970                                         yes
# Soyinka,The_Interpreters,1970                                           yes
# ...                                                                ...  ...
# Tadjo,As_the_Crow_Flies,2001                                            yes
# Pepetela_,Return_of_the_Water_Spirit,2002                               yes
# Tadjo,The_Shadow_of_Imana,2002                                          yes
# Aidoo,Changes,2003                              Aidoo,Changes,2003.txt  yes
# Mengara,Mema,2003                                                       yes
#
#                                                hitem_id number  genre  \
# id
# Ngugi,The_River_Between,1965                              17.0  novel
# Ngugi,A_Grain_of_Wheat,1967                               36.0  novel
# Armah,The_Beautyful_Ones_Are_Not_Yet_Born,1969            43.0  novel
# Ousmane,God's_Bits_of_Wood,1970                           63.0  novel
# Soyinka,The_Interpreters,1970                             76.0  novel
# ...                                                 ...    ...    ...
# Tadjo,As_the_Crow_Flies,2001                                    novel
# Pepetela_,Return_of_the_Water_Spirit,2002                       novel
# Tadjo,The_Shadow_of_Imana,2002                                  novel
# Aidoo,Changes,2003                                              novel
# Mengara,Mema,2003                                               novel
#
#                                                anthology  ...    nationality  \
# id                                                        ...
# Ngugi,The_River_Between,1965                          no  ...          Kenya
# Ngugi,A_Grain_of_Wheat,1967                           no  ...          Kenya
# Armah,The_Beautyful_Ones_Are_Not_Yet_Born,1969        no  ...          Ghana
# Ousmane,God's_Bits_of_Wood,1970                       no  ...        Senegal
# Soyinka,The_Interpreters,1970                         no  ...        Nigeria
# ...                                                  ...  ...            ...
# Tadjo,As_the_Crow_Flies,2001                          no  ...  Côte d'Ivoire
# Pepetela_,Return_of_the_Water_Spirit,2002             no  ...         Angola
# Tadjo,The_Shadow_of_Imana,2002                        no  ...  Côte d'Ivoire
# Aidoo,Changes,2003                                    no  ...          Ghana
# Mengara,Mema,2003                                     no  ...          Gabon
#
#                                                origpubdate  \
# id
# Ngugi,The_River_Between,1965
# Ngugi,A_Grain_of_Wheat,1967
# Armah,The_Beautyful_Ones_Are_Not_Yet_Born,1969      1968.0
# Ousmane,God's_Bits_of_Wood,1970
# Soyinka,The_Interpreters,1970                       1965.0
# ...                                                    ...
# Tadjo,As_the_Crow_Flies,2001
# Pepetela_,Return_of_the_Water_Spirit,2002
# Tadjo,The_Shadow_of_Imana,2002
# Aidoo,Changes,2003
# Mengara,Mema,2003
#
#                                                                                              note  \
# id
# Ngugi,The_River_Between,1965
# Ngugi,A_Grain_of_Wheat,1967
# Armah,The_Beautyful_Ones_Are_Not_Yet_Born,1969
# Ousmane,God's_Bits_of_Wood,1970
# Soyinka,The_Interpreters,1970                   With introduction and notes by Eldred Jones. L...
# ...                                                                                           ...
# Tadjo,As_the_Crow_Flies,2001
# Pepetela_,Return_of_the_Water_Spirit,2002
# Tadjo,The_Shadow_of_Imana,2002
# Aidoo,Changes,2003
# Mengara,Mema,2003
#
#                                                  lastname  \
# id
# Ngugi,The_River_Between,1965                        Ngugi
# Ngugi,A_Grain_of_Wheat,1967                         Ngugi
# Armah,The_Beautyful_Ones_Are_Not_Yet_Born,1969      Armah
# Ousmane,God's_Bits_of_Wood,1970                   Sembène
# Soyinka,The_Interpreters,1970                     Soyinka
# ...                                                   ...
# Tadjo,As_the_Crow_Flies,2001                        Tadjo
# Pepetela_,Return_of_the_Water_Spirit,2002       Pepetela_
# Tadjo,The_Shadow_of_Imana,2002                      Tadjo
# Aidoo,Changes,2003                                  Aidoo
# Mengara,Mema,2003                                 Mengara
#
#                                                                          shorttitle  \
# id
# Ngugi,The_River_Between,1965                                      The_River_Between
# Ngugi,A_Grain_of_Wheat,1967                                        A_Grain_of_Wheat
# Armah,The_Beautyful_Ones_Are_Not_Yet_Born,1969  The_Beautyful_Ones_Are_Not_Yet_Born
# Ousmane,God's_Bits_of_Wood,1970                                  God's_Bits_of_Wood
# Soyinka,The_Interpreters,1970                                      The_Interpreters
# ...                                                                             ...
# Tadjo,As_the_Crow_Flies,2001                                      As_the_Crow_Flies
# Pepetela_,Return_of_the_Water_Spirit,2002                Return_of_the_Water_Spirit
# Tadjo,The_Shadow_of_Imana,2002                                  The_Shadow_of_Imana
# Aidoo,Changes,2003                                                          Changes
# Mengara,Mema,2003                                                              Mema
#
#                                                                                        path_freqs  \
# id
# Ngugi,The_River_Between,1965                    /Users/tobywarner/lltk_data/corpora/aws__novel...
# Ngugi,A_Grain_of_Wheat,1967                     /Users/tobywarner/lltk_data/corpora/aws__novel...
# Armah,The_Beautyful_Ones_Are_Not_Yet_Born,1969  /Users/tobywarner/lltk_data/corpora/aws__novel...
# Ousmane,God's_Bits_of_Wood,1970                 /Users/tobywarner/lltk_data/corpora/aws__novel...
# Soyinka,The_Interpreters,1970                   /Users/tobywarner/lltk_data/corpora/aws__novel...
# ...                                                                                           ...
# Tadjo,As_the_Crow_Flies,2001                    /Users/tobywarner/lltk_data/corpora/aws__novel...
# Pepetela_,Return_of_the_Water_Spirit,2002       /Users/tobywarner/lltk_data/corpora/aws__novel...
# Tadjo,The_Shadow_of_Imana,2002                  /Users/tobywarner/lltk_data/corpora/aws__novel...
# Aidoo,Changes,2003                              /Users/tobywarner/lltk_data/corpora/aws__novel...
# Mengara,Mema,2003                               /Users/tobywarner/lltk_data/corpora/aws__novel...
#
#                                                                                          path_txt  \
# id
# Ngugi,The_River_Between,1965                    /Users/tobywarner/Dropbox/textmining/corpora/a...
# Ngugi,A_Grain_of_Wheat,1967                     /Users/tobywarner/Dropbox/textmining/corpora/a...
# Armah,The_Beautyful_Ones_Are_Not_Yet_Born,1969  /Users/tobywarner/Dropbox/textmining/corpora/a...
# Ousmane,God's_Bits_of_Wood,1970                 /Users/tobywarner/Dropbox/textmining/corpora/a...
# Soyinka,The_Interpreters,1970                   /Users/tobywarner/Dropbox/textmining/corpora/a...
# ...                                                                                           ...
# Tadjo,As_the_Crow_Flies,2001                    /Users/tobywarner/Dropbox/textmining/corpora/a...
# Pepetela_,Return_of_the_Water_Spirit,2002       /Users/tobywarner/Dropbox/textmining/corpora/a...
# Tadjo,The_Shadow_of_Imana,2002                  /Users/tobywarner/Dropbox/textmining/corpora/a...
# Aidoo,Changes,2003                              /Users/tobywarner/Dropbox/textmining/corpora/a...
# Mengara,Mema,2003                               /Users/tobywarner/Dropbox/textmining/corpora/a...
#
#                                                                                          path_xml  \
# id
# Ngugi,The_River_Between,1965                    /Users/tobywarner/lltk_data/corpora/aws__novel...
# Ngugi,A_Grain_of_Wheat,1967                     /Users/tobywarner/lltk_data/corpora/aws__novel...
# Armah,The_Beautyful_Ones_Are_Not_Yet_Born,1969  /Users/tobywarner/lltk_data/corpora/aws__novel...
# Ousmane,God's_Bits_of_Wood,1970                 /Users/tobywarner/lltk_data/corpora/aws__novel...
# Soyinka,The_Interpreters,1970                   /Users/tobywarner/lltk_data/corpora/aws__novel...
# ...                                                                                           ...
# Tadjo,As_the_Crow_Flies,2001                    /Users/tobywarner/lltk_data/corpora/aws__novel...
# Pepetela_,Return_of_the_Water_Spirit,2002       /Users/tobywarner/lltk_data/corpora/aws__novel...
# Tadjo,The_Shadow_of_Imana,2002                  /Users/tobywarner/lltk_data/corpora/aws__novel...
# Aidoo,Changes,2003                              /Users/tobywarner/lltk_data/corpora/aws__novel...
# Mengara,Mema,2003                               /Users/tobywarner/lltk_data/corpora/aws__novel...
#
#                                                _year_orig      corpus
# id
# Ngugi,The_River_Between,1965                         1965  AWS_Novels
# Ngugi,A_Grain_of_Wheat,1967                          1967  AWS_Novels
# Armah,The_Beautyful_Ones_Are_Not_Yet_Born,1969       1969  AWS_Novels
# Ousmane,God's_Bits_of_Wood,1970                      1970  AWS_Novels
# Soyinka,The_Interpreters,1970                        1970  AWS_Novels
# ...                                                   ...         ...
# Tadjo,As_the_Crow_Flies,2001                         2001  AWS_Novels
# Pepetela_,Return_of_the_Water_Spirit,2002            2002  AWS_Novels
# Tadjo,The_Shadow_of_Imana,2002                       2002  AWS_Novels
# Aidoo,Changes,2003                                   2003  AWS_Novels
# Mengara,Mema,2003                                    2003  AWS_Novels
#
# [163 rows x 24 columns]

# %%
# here we need to conserve capitalization for tokens or use a better tagger? nltk_pos after lower is reading all the proper names as NN instead of NNP
def tokenize_pos(text, pos='NN'):
    tokens = tokenize_fast(text)
    tagged_tokens = nltk.pos_tag(tokens)
   # tokens2=[]
    #    for w,p in tagged_tokens:
     #   if p == pos:
      #  tokens2.append(w)
       # tokens2=[]
    tokens2 = [
        w
        for w,p in tagged_tokens
        if p==pos
    ]   
    return tokens2

# %%
story2 = "Okonkwo was well known throughout the nine villages and even beyond. His fame rested on solid personal achievements. As a young man of eighteen he had brought honour to his village by throwing Amalinze the Cat. Amalinze was the great wrestler who for seven years was unbeaten, from Umuofia to Mbaino. He was called the Cat because his back would never touch the earth. It was this man that Okonkwo threw in a fight which the old men agreed was one of the fiercest since the founder of their town engaged a spirit of the wild for seven days and seven nights. The drums beat and the flutes sang and the spectators held their breath. Amalinze was a wily craftsman, but Okonkwo was as slippery as a fish in water. Every nerve and every muscle stood out on their arms, on their backs and their thighs, and one almost heard them stretching to breaking point. In the end Okonkwo threw the Cat. That was many years ago, twenty years or more, and during this time Okonkwo's fame had grown like a bush-fire in the harmattan. He was tall and huge, and his bushy eyebrows and wide nose gave him a very severe look. He breathed heavily, and it was said that, when he slept, his wives and children in their out-houses could hear him breathe. When he walked, his heels hardly touched the ground and he seemed to walk on springs, as if he was going to pounce on somebody. And he did pounce on people quite often. He had a slight stammer and whenever he was angry and could not get his words out quickly enough, he would use his fists. He had no patience with unsuccessful men. He had had no patience with his father. Unoka, for that was his father's name, had died ten years ago. In his day he was lazy and improvident and was quite incapable of thinking about tomorrow. If any money came his way, and it seldom did, he immediately bought gourds of palm-wine, called round his neighbours and made merry. He always said that whenever he saw a dead man's mouth he saw the folly of not eating what one had in one's lifetime. Unoka was, of course, a debtor, and he owed every neighbour some money, from a few cowries to quite substantial amounts. He was tall but very thin and had a slight stoop. He wore a haggard and mournful look except when he was drinking or playing on his flute. He was very good on his flute, and his happiest moments were the two or three moons after the harvest when the village musicians brought down their instruments, hung above the fireplace. Unoka would play with them, his face beaming with blessedness and peace. Sometimes another village would ask Unoka's band and their dancing egwugwu to come and stay with them and teach them their tunes. They would go to such hosts for as long as three or four markets, making music and feasting. Unoka loved the good fare and the good fellowship, and he loved this season of the year, when the rains had stopped and the sun rose every morning with dazzling beauty. And it was not too hot either, because the cold and dry harmattan wind was blowing down from the north. Some years the harmattan was very severe and a dense haze hung on the atmosphere. Old men and children would then sit round log fires, warming their bodies. Unoka loved it all, and he loved the first kites that returned with the dry season, and the children who sang songs of welcome to them. He would remember his own childhood, how he had often wandered around looking for a kite sailing leisurely against the blue sky. As soon as he found one he would sing with his whole being, welcoming it back from its long, long journey, and asking it if it had brought home any lengths of cloth. That was years ago, when he was young. Unoka, the grown-up, was a failure. He was poor and his wife and children had barely enough to eat. People laughed at him because he was a loafer, and they swore never to lend him any more money because he never paid back. But Unoka was such a man that he always succeeded in borrowing more, and piling up his debts. One day a neighbour called Okoye came in to see him. He was reclining on a mud bed in his hut playing on the flute. He immediately rose and shook hands with Okoye, who then unrolled the goatskin which he carried under his arm, and sat down. Unoka went into an inner room and soon returned with a small wooden disc containing a kola nut, some alligator pepper and a lump of white chalk. “I have kola,” he announced when he sat down, and passed the disc over to his guest. “Thank you. He who brings kola brings life. But I think you ought to break it,” replied Okoye passing back the disc. “No, it is for you, I think,” and they argued like this for a few moments before Unoka accepted the honour of breaking the kola. Okoye, meanwhile, took the lump of chalk, drew some lines on the floor, and then painted his big toe."

# %%
tokenize_pos(story2)
# Out:
# ['okonkwo',
#  'fame',
#  'man',
#  'eighteen',
#  'honour',
#  'village',
#  'cat',
#  'amalinze',
#  'wrestler',
#  'cat',
#  'back',
#  'earth',
#  'man',
#  'threw',
#  'fight',
#  'founder',
#  'town',
#  'spirit',
#  'wild',
#  'beat',
#  'breath',
#  'amalinze',
#  'craftsman',
#  'okonkwo',
#  'fish',
#  'water',
#  'nerve',
#  'muscle',
#  'point',
#  'end',
#  'okonkwo',
#  'cat',
#  'time',
#  'fame',
#  'bush-fire',
#  'harmattan',
#  'bushy',
#  'look',
#  'ground',
#  'somebody',
#  'stammer',
#  'whenever',
#  'patience',
#  'patience',
#  'father',
#  'unoka',
#  "father's",
#  'name',
#  'day',
#  'tomorrow',
#  'money',
#  'way',
#  'palm-wine',
#  'merry',
#  'whenever',
#  "man's",
#  'mouth',
#  'folly',
#  'lifetime',
#  'unoka',
#  'course',
#  'debtor',
#  'money',
#  'stoop',
#  'haggard',
#  'look',
#  'flute',
#  'flute',
#  'harvest',
#  'village',
#  'fireplace',
#  'unoka',
#  'face',
#  'blessedness',
#  'peace',
#  'village',
#  'band',
#  'dancing',
#  'egwugwu',
#  'music',
#  'fare',
#  'fellowship',
#  'season',
#  'year',
#  'sun',
#  'morning',
#  'beauty',
#  'harmattan',
#  'wind',
#  'harmattan',
#  'dense',
#  'haze',
#  'hung',
#  'round',
#  'log',
#  'season',
#  'welcome',
#  'childhood',
#  'sailing',
#  'sky',
#  'journey',
#  'home',
#  'cloth',
#  'grown-up',
#  'failure',
#  'wife',
#  'loafer',
#  'money',
#  'unoka',
#  'man',
#  'day',
#  'neighbour',
#  'okoye',
#  'mud',
#  'bed',
#  'hut',
#  'playing',
#  'flute',
#  'okoye',
#  'goatskin',
#  'arm',
#  'room',
#  'disc',
#  'kola',
#  'alligator',
#  'pepper',
#  'lump',
#  'chalk',
#  'i',
#  'disc',
#  'thank',
#  'kola',
#  'life',
#  'disc',
#  'honour',
#  'kola',
#  'okoye',
#  'lump',
#  'chalk',
#  'floor',
#  'toe']

# %%
import nltk
from nltk.corpus import stopwords

# %%
# a function to tokenize and remove stopwords / small words
def tokenize_pos_lower (text, pos='NN', stop_words=stopwords.words('english')):
    tokens = tokenize_fast(text)
    tagged_tokens = nltk.pos_tag(tokens)
   # tokens2=[]
    #    for w,p in tagged_tokens:
     #   if p == pos:
      #  tokens2.append(w)
       # tokens2=[]
    tokens2 = [
        w
        for w,p in tagged_tokens
        if p==pos and len(w)>3 and w.lower not in stop_words
    ]   
    return tokens2

# %%
tokenize_pos_lower(story2)
# Out:
# ['okonkwo',
#  'fame',
#  'eighteen',
#  'honour',
#  'village',
#  'amalinze',
#  'wrestler',
#  'back',
#  'earth',
#  'threw',
#  'fight',
#  'founder',
#  'town',
#  'spirit',
#  'wild',
#  'beat',
#  'breath',
#  'amalinze',
#  'craftsman',
#  'okonkwo',
#  'fish',
#  'water',
#  'nerve',
#  'muscle',
#  'point',
#  'okonkwo',
#  'time',
#  'fame',
#  'bush-fire',
#  'harmattan',
#  'bushy',
#  'look',
#  'ground',
#  'somebody',
#  'stammer',
#  'whenever',
#  'patience',
#  'patience',
#  'father',
#  'unoka',
#  "father's",
#  'name',
#  'tomorrow',
#  'money',
#  'palm-wine',
#  'merry',
#  'whenever',
#  "man's",
#  'mouth',
#  'folly',
#  'lifetime',
#  'unoka',
#  'course',
#  'debtor',
#  'money',
#  'stoop',
#  'haggard',
#  'look',
#  'flute',
#  'flute',
#  'harvest',
#  'village',
#  'fireplace',
#  'unoka',
#  'face',
#  'blessedness',
#  'peace',
#  'village',
#  'band',
#  'dancing',
#  'egwugwu',
#  'music',
#  'fare',
#  'fellowship',
#  'season',
#  'year',
#  'morning',
#  'beauty',
#  'harmattan',
#  'wind',
#  'harmattan',
#  'dense',
#  'haze',
#  'hung',
#  'round',
#  'season',
#  'welcome',
#  'childhood',
#  'sailing',
#  'journey',
#  'home',
#  'cloth',
#  'grown-up',
#  'failure',
#  'wife',
#  'loafer',
#  'money',
#  'unoka',
#  'neighbour',
#  'okoye',
#  'playing',
#  'flute',
#  'okoye',
#  'goatskin',
#  'room',
#  'disc',
#  'kola',
#  'alligator',
#  'pepper',
#  'lump',
#  'chalk',
#  'disc',
#  'thank',
#  'kola',
#  'life',
#  'disc',
#  'honour',
#  'kola',
#  'okoye',
#  'lump',
#  'chalk',
#  'floor']

# %%
#from tqdm import tqdm
#texts = [tokenize_pos(t.txt) for t in tqdm(C.texts())]

# %% [markdown]
# # Topic Models

# %%
from tqdm import tqdm

texts2 = [tokenize_pos_lower(t.txt) for t in tqdm(C.texts())]
# Out:
# 100%|██████████| 163/163 [06:03<00:00,  2.23s/it]

# %%
from gensim import corpora

dictionary = corpora.Dictionary(texts)
dictionary.filter_extremes(no_below=5, no_above=0.7, keep_n=4000) #paramaters to tweak
corpus = [dictionary.doc2bow(text) for text in texts2]

# %%
from gensim import models

n_topics = 18

lda_model = models.LdaModel(corpus=corpus, num_topics=n_topics)

# %% [markdown]
# ## Increasing no_above results in tokens that are more common across the whole corpus
# ## Decreasing no_above_ results in tokens that are less common

# %%
import pyLDAvis
import pyLDAvis.gensim_models
pyLDAvis.enable_notebook()
vis = pyLDAvis.gensim_models.prepare(lda_model, corpus, dictionary)
vis

# %%
dictionary = corpora.Dictionary(texts)
dictionary.filter_extremes(no_below=5, no_above=0.8, keep_n=1000)  #paramaters to tweak
corpus = [dictionary.doc2bow(text) for text in texts2]
n_topics = 18
lda_model = models.LdaModel(corpus=corpus, num_topics=n_topics)
pyLDAvis.enable_notebook()
vis = pyLDAvis.gensim_models.prepare(lda_model, corpus, dictionary)
vis

# %%
dictionary = corpora.Dictionary(texts)
dictionary.filter_extremes(no_below=5, no_above=0.2, keep_n=2000)  #paramaters to tweak
corpus = [dictionary.doc2bow(text) for text in texts2]
n_topics = 18
lda_model = models.LdaModel(corpus=corpus, num_topics=n_topics)
pyLDAvis.enable_notebook()
vis = pyLDAvis.gensim_models.prepare(lda_model, corpus, dictionary)
vis
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-816edf5cedc4> in <module>
# ----> 1 dictionary = corpora.Dictionary(texts)
#       2 dictionary.filter_extremes(no_below=5, no_above=0.2, keep_n=2000)  #paramaters to tweak
#       3 corpus = [dictionary.doc2bow(text) for text in texts2]
#       4 n_topics = 18
#       5 lda_model = models.LdaModel(corpus=corpus, num_topics=n_topics)
#
# NameError: name 'corpora' is not defined

# %%
## Getting Set up
